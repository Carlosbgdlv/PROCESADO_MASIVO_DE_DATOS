# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import pylab
import scipy.stats as ss
import csv
import numpy as np
import sklearn
import glob
from io import StringIO
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
csv_filename = 'C:/Users/ywen2/Desktop/URJC/PROCESADO MASIVO DE DATOS/PROCESADO_MASIVO_DE_DATOS/country_vaccinations.csv'

with open(csv_filename, 'r') as archivo:
    leer = csv.reader(archivo)
    lista = list(leer)
df = pd.DataFrame(lista)
df
# Out:
#                  0         1           2                   3  \
# 0          country  iso_code        date  total_vaccinations
# 1      Afghanistan       AFG  2021-02-22                 0.0
# 2      Afghanistan       AFG  2021-02-23
# 3      Afghanistan       AFG  2021-02-24
# 4      Afghanistan       AFG  2021-02-25
# ...            ...       ...         ...                 ...
# 12966     Zimbabwe       ZWE  2021-04-15            285881.0
# 12967     Zimbabwe       ZWE  2021-04-16            304701.0
# 12968     Zimbabwe       ZWE  2021-04-17            311901.0
# 12969     Zimbabwe       ZWE  2021-04-18            314446.0
# 12970     Zimbabwe       ZWE  2021-04-19            316991.0
#
#                        4                        5                       6  \
# 0      people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw
# 1                    0.0
# 2
# 3
# 4
# ...                  ...                      ...                     ...
# 12966           252932.0                  32949.0                 23753.0
# 12967           269732.0                  34969.0                 18820.0
# 12968           276095.0                  35806.0                  7200.0
# 12969           278583.0                  35863.0                  2545.0
# 12970           280568.0                  36423.0                  2545.0
#
#                         7                               8  \
# 0      daily_vaccinations  total_vaccinations_per_hundred
# 1                                                     0.0
# 2                  1367.0
# 3                  1367.0
# 4                  1367.0
# ...                   ...                             ...
# 12966             13172.0                            1.92
# 12967             14071.0                            2.05
# 12968             12738.0                             2.1
# 12969             12993.0                            2.12
# 12970             11773.0                            2.13
#
#                                    9                                   10  \
# 0      people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred
# 1                                0.0
# 2
# 3
# 4
# ...                              ...                                  ...
# 12966                            1.7                                 0.22
# 12967                           1.81                                 0.24
# 12968                           1.86                                 0.24
# 12969                           1.87                                 0.24
# 12970                           1.89                                 0.25
#
#                                    11                  12  \
# 0      daily_vaccinations_per_million            vaccines
# 1                                      Oxford/AstraZeneca
# 2                                35.0  Oxford/AstraZeneca
# 3                                35.0  Oxford/AstraZeneca
# 4                                35.0  Oxford/AstraZeneca
# ...                               ...                 ...
# 12966                           886.0   Sinopharm/Beijing
# 12967                           947.0   Sinopharm/Beijing
# 12968                           857.0   Sinopharm/Beijing
# 12969                           874.0   Sinopharm/Beijing
# 12970                           792.0   Sinopharm/Beijing
#
#                               13  \
# 0                    source_name
# 1      Government of Afghanistan
# 2      Government of Afghanistan
# 3      Government of Afghanistan
# 4      Government of Afghanistan
# ...                          ...
# 12966         Ministry of Health
# 12967         Ministry of Health
# 12968         Ministry of Health
# 12969         Ministry of Health
# 12970         Ministry of Health
#
#                                                       14
# 0                                         source_website
# 1      http://www.xinhuanet.com/english/asiapacific/2...
# 2      http://www.xinhuanet.com/english/asiapacific/2...
# 3      http://www.xinhuanet.com/english/asiapacific/2...
# 4      http://www.xinhuanet.com/english/asiapacific/2...
# ...                                                  ...
# 12966  https://twitter.com/MoHCCZim/status/1384225499...
# 12967  https://twitter.com/MoHCCZim/status/1384225499...
# 12968  https://twitter.com/MoHCCZim/status/1384225499...
# 12969  https://twitter.com/MoHCCZim/status/1384225499...
# 12970  https://twitter.com/MoHCCZim/status/1384225499...
#
# [12971 rows x 15 columns]

# %%
csv_filename_1 = 'C:/Users/ywen2/Desktop/URJC/PROCESADO MASIVO DE DATOS/PROCESADO_MASIVO_DE_DATOS/country_vaccinations_by_manufacturer.csv'

with open(csv_filename_1, 'r') as archivo_1:
    leer_1 = csv.reader(archivo_1)
    lista_1 = list(leer_1)
df_1 = pd.DataFrame(lista_1)
df_1
# Out:
#                   0           1                2                   3
# 0          location        date          vaccine  total_vaccinations
# 1             Chile  2020-12-24  Pfizer/BioNTech                 420
# 2             Chile  2020-12-25  Pfizer/BioNTech                5198
# 3             Chile  2020-12-26  Pfizer/BioNTech                8338
# 4             Chile  2020-12-27  Pfizer/BioNTech                8649
# ...             ...         ...              ...                 ...
# 2501  United States  2021-04-19          Moderna            93002433
# 2502  United States  2021-04-19  Pfizer/BioNTech           110461905
# 2503  United States  2021-04-20  Johnson&Johnson             7961251
# 2504  United States  2021-04-20          Moderna            93672874
# 2505  United States  2021-04-20  Pfizer/BioNTech           111585824
#
# [2506 rows x 4 columns]

# %% [markdown]
# HOLA BUENAA TARDES
